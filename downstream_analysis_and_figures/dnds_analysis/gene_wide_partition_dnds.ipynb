# %%
import pandas as pd
import subprocess
from Bio import Entrez, SeqIO
import ast
import os
import numpy as np

# %%
dfc=pd.read_csv("revised_cluster_info_v3.csv",index_col=0)

# %%
dfc=dfc[dfc.n_species>1]

# %% [markdown]
# ## Run PAML for dn/ds for all chimeras in >1 species

# %% [markdown]
# Prep: fasta downloads for all secondary chimeras, concatenation, MSA generation and tree inference

# %%
for c in dfc[dfc.n_species>1].sort_values("n_species").index:
    if c not in os.listdir("dnds"):
        print(c)
        subprocess.run(["mkdir", f"dnds/{c}"])
        #download protein and nucleotide fastas 
        sec_chimeras=ast.literal_eval(dfc.loc[c,:].secondary_chimeras)
        for acc in sec_chimeras:
            subprocess.run(["mkdir", f"dnds/{c}/{acc}"])
            url_na=f"http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id={acc}&rettype=fasta_cds_na" 
            url_prot=f"http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id={acc}&rettype=fasta" 
            subprocess.run(["wget",url_na,"-O",f"dnds/{c}/{acc}/nuc.fasta"])
            subprocess.run(["wget",url_prot,"-O",f"dnds/{c}/{acc}/prot.fasta"])

        main_directory =f"dnds/{c}"

        # Create an output file for concatenated sequences
        output_nuc = f"dnds/{c}/concatenated_nuc.fasta"
        output_prot = f"dnds/{c}/concatenated_prot.fasta"

        # Initialize an empty list to store sequences
        all_nucs = []
        all_prots = []

        # Iterate through subdirectories and create a list of all fastas
        #Written by RK w/ ChatGPT
        for subdir in os.listdir(main_directory):
            subdirectory_path = os.path.join(main_directory, subdir)

            if os.path.isdir(subdirectory_path):
                nuc_fasta_file = os.path.join(subdirectory_path, "nuc.fasta")
                prot_fasta_file = os.path.join(subdirectory_path, "prot.fasta")
                if os.path.exists(nuc_fasta_file):
                    # Read the sequences from nuc.fasta and add to the list
                    sequences = list(SeqIO.parse(nuc_fasta_file, "fasta"))
                    all_nucs.extend(sequences)

                if os.path.exists(prot_fasta_file):
                    # Read the sequences from nuc.fasta and add to the list
                    sequences = list(SeqIO.parse(prot_fasta_file, "fasta"))
                    all_prots.extend(sequences)

        # Write the concatenated sequences to the output file
        with open(output_nuc, "w") as output_handle:
            SeqIO.write(all_nucs, output_handle, "fasta")

        with open(output_prot, "w") as output_handle:
            SeqIO.write(all_prots, output_handle, "fasta")
        
        
        input_file = open(f"dnds/{c}/concatenated_prot.fasta")
        prot_dict = SeqIO.to_dict(SeqIO.parse(input_file, "fasta"))
        input_file = open(f"dnds/{c}/concatenated_nuc.fasta")
        nuc_dict = SeqIO.to_dict(SeqIO.parse(input_file, "fasta"))
        
        f=open(f"dnds/{c}/concatenated_nuc.fasta","w")
        f1=open(f"dnds/{c}/concatenated_prot.fasta","w")
        for p in prot_dict.keys():
            kn=[x for x in nuc_dict.keys() if p in x]
            if len(kn)>0:
                kn=kn[0]
                f.write(f">{kn}")
                f.write("\n")
                f.write(str(nuc_dict[kn].seq))
                f.write("\n")

                f1.write(f">{p}")
                f1.write("\n")
                f1.write(str(prot_dict[p].seq))
                f1.write("\n")
        f.close()
        f1.close()
        
        if int(dfc.loc[c,"n_species"])==2:
            print("Concatenation complete.")
            f=open(f"dnds/{c}/tree.newick","w")
            f.write("(")
            f.write(str(all_prots[0].name))
            f.write(":1,")
            f.write(str(all_prots[1].name))
            f.write(":1")
            f.write(");")
            f.close()
            subprocess.run(["sh","dnds_scripts/run_muscle.sh", str(c)])
        else:
            subprocess.run(["sbatch","dnds_scripts/run_iqtree_pipe.sh", str(c)])
# Out:
# XP_033212670.1
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:27--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAD6241409.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAD6241409.1/nuc.fasta’
#
#      0K ......                                                 93.6M=0s
#
# 2023-09-06 15:51:28 (93.6 MB/s) - ‘dnds/XP_033212670.1/CAD6241409.1/nuc.fasta’ saved [6271]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:29--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAD6241409.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAD6241409.1/prot.fasta’
#
#      0K ..                                                     21.0M=0s
#
# 2023-09-06 15:51:29 (21.0 MB/s) - ‘dnds/XP_033212670.1/CAD6241409.1/prot.fasta’ saved [2068]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:29--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_046745747.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_046745747.1/nuc.fasta’
#
#      0K .....                                                  54.4M=0s
#
# 2023-09-06 15:51:30 (54.4 MB/s) - ‘dnds/XP_033212670.1/XP_046745747.1/nuc.fasta’ saved [5748]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:30--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_046745747.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_046745747.1/prot.fasta’
#
#      0K .                                                      73.9M=0s
#
# 2023-09-06 15:51:30 (73.9 MB/s) - ‘dnds/XP_033212670.1/XP_046745747.1/prot.fasta’ saved [1922]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:30--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH7727487.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH7727487.1/nuc.fasta’
#
#      0K ....                                                   30.9M=0s
#
# 2023-09-06 15:51:31 (30.9 MB/s) - ‘dnds/XP_033212670.1/CAH7727487.1/nuc.fasta’ saved [4333]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:31--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH7727487.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH7727487.1/prot.fasta’
#
#      0K .                                                      63.2M=0s
#
# 2023-09-06 15:51:32 (63.2 MB/s) - ‘dnds/XP_033212670.1/CAH7727487.1/prot.fasta’ saved [1373]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:32--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_050332734.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_050332734.1/nuc.fasta’
#
#      0K .....                                                  50.4M=0s
#
# 2023-09-06 15:51:32 (50.4 MB/s) - ‘dnds/XP_033212670.1/XP_050332734.1/nuc.fasta’ saved [5763]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:32--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_050332734.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_050332734.1/prot.fasta’
#
#      0K .                                                      74.2M=0s
#
# 2023-09-06 15:51:33 (74.2 MB/s) - ‘dnds/XP_033212670.1/XP_050332734.1/prot.fasta’ saved [1935]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:33--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0389597.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0389597.1/nuc.fasta’
#
#      0K .....                                                  85.7M=0s
#
# 2023-09-06 15:51:34 (85.7 MB/s) - ‘dnds/XP_033212670.1/CAH0389597.1/nuc.fasta’ saved [5653]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:34--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0389597.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0389597.1/prot.fasta’
#
#      0K .                                                      69.9M=0s
#
# 2023-09-06 15:51:34 (69.9 MB/s) - ‘dnds/XP_033212670.1/CAH0389597.1/prot.fasta’ saved [1767]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:34--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_055322824.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_055322824.1/nuc.fasta’
#
#      0K ...                                                     140M=0s
#
# 2023-09-06 15:51:35 (140 MB/s) - ‘dnds/XP_033212670.1/XP_055322824.1/nuc.fasta’ saved [3763]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:35--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_055322824.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_055322824.1/prot.fasta’
#
#      0K .                                                      42.9M=0s
#
# 2023-09-06 15:51:35 (42.9 MB/s) - ‘dnds/XP_033212670.1/XP_055322824.1/prot.fasta’ saved [1274]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:35--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_019755807.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_019755807.1/nuc.fasta’
#
#      0K ....                                                   41.1M=0s
#
# 2023-09-06 15:51:36 (41.1 MB/s) - ‘dnds/XP_033212670.1/XP_019755807.1/nuc.fasta’ saved [4665]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51

#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:44--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_018392777.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_018392777.1/prot.fasta’
#
#      0K ..                                                     80.0M=0s
#
# 2023-09-06 15:51:45 (80.0 MB/s) - ‘dnds/XP_033212670.1/XP_018392777.1/prot.fasta’ saved [2101]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:45--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_029040982.2&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_029040982.2/nuc.fasta’
#
#      0K .....                                                   187M=0s
#
# 2023-09-06 15:51:45 (187 MB/s) - ‘dnds/XP_033212670.1/XP_029040982.2/nuc.fasta’ saved [5198]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:45--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_029040982.2&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_029040982.2/prot.fasta’
#
#      0K .                                                      67.6M=0s
#
# 2023-09-06 15:51:46 (67.6 MB/s) - ‘dnds/XP_033212670.1/XP_029040982.2/prot.fasta’ saved [1731]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:46--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_049873921.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_049873921.1/nuc.fasta’
#
#      0K ....                                                   37.4M=0s
#
# 2023-09-06 15:51:46 (37.4 MB/s) - ‘dnds/XP_033212670.1/XP_049873921.1/nuc.fasta’ saved [4532]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:46--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_049873921.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_049873921.1/prot.fasta’
#
#      0K .                                                      57.9M=0s
#
# 2023-09-06 15:51:47 (57.9 MB/s) - ‘dnds/XP_033212670.1/XP_049873921.1/prot.fasta’ saved [1533]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:47--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_044589240.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_044589240.1/nuc.fasta’
#
#      0K ......                                                 56.0M=0s
#
# 2023-09-06 15:51:47 (56.0 MB/s) - ‘dnds/XP_033212670.1/XP_044589240.1/nuc.fasta’ saved [6246]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:47--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_044589240.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_044589240.1/prot.fasta’
#
#      0K ..                                                     84.6M=0s
#
# 2023-09-06 15:51:48 (84.6 MB/s) - ‘dnds/XP_033212670.1/XP_044589240.1/prot.fasta’ saved [2097]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:48--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KOX75801.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KOX75801.1/nuc.fasta’
#
#      0K ....                                                   33.5M=0s
#
# 2023-09-06 15:51:49 (33.5 MB/s) - ‘dnds/XP_033212670.1/KOX75801.1/nuc.fasta’ saved [5030]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:49--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KOX75801.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KOX75801.1/prot.fasta’
#
#      0K .                                                      16.1M=0s
#
# 2023-09-06 15:51:49 (16.1 MB/s) - ‘dnds/XP_033212670.1/KOX75801.1/prot.fasta’ saved [1618]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:49--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0398792.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0398792.1/nuc.fasta’
#
#      0K ....                                                   98.8M=0s
#
# 2023-09-06 15:51:50 (98.8 MB/s) - ‘dnds/XP_033212670.1/CAH0398792.1/nuc.fasta’ saved [4800]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:50--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0398792.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0398792.1/prot.fasta’
#
#      0K .                                                      58.7M=0s
#
# 2023-09-06 15:51:50 (58.7 MB/s) - ‘dnds/XP_033212670.1/CAH0398792.1/prot.fasta’ saved [1514]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:50--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_016911196.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_016911196.1/nuc.fasta’
#
#      0K .....                                                  40.2M=0s
#
# 2023-09-06 15:51:51 (40.2 MB/s) - ‘dnds/XP_033212670.1/XP_016911196.1/nuc.fasta’ saved [5436]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:51--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_016911196.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_016911196.1/prot.fasta’
#
#      0K .                                                      75.0M=0s
#
# 2023-09-06 15:51:51 (75.0 MB/s) - ‘dnds/XP_033212670.1/XP_016911196.1/prot.fasta’ saved [1798]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:51--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_038223624.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_038223624.1/nuc.fasta’
#
#      0K ....                                                   38.4M=0s
#
# 2023-09-06 15:51:52 (38.4 MB/s) - ‘dnds/XP_033212670.1/XP_038223624.1/nuc.fasta’ saved [4309]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:52--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_038223624.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_038223624.1/prot.fasta’
#
#      0K .                                                      72.9M=0s
#
# 2023-09-06 15:51:52 (72.9 MB/s) - ‘dnds/XP_033212670.1/XP_038223624.1/prot.fasta’ saved [1435]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:52--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_018569595.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_018569595.1/nuc.fasta’
#
#      0K ...                                                     143M=0s
#
# 2023-09-06 15:51:53 (143 MB/s) - ‘dnds/XP_033212670.1/XP_018569595.1/nuc.fasta’ saved [3854]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:53--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_018569595.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_018569595.1/prot.fasta’
#
#      0K .                                                       117K=0.01s
#
# 2023-09-06 15:51:54 (117 KB/s) - ‘dnds/XP_033212670.1/XP_018569595.1/prot.fasta’ saved [1301]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:54--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAG5873401.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAG5873401.1/nuc.fasta’
#
#      0K ...                                                    9.24M=0s
#
# 2023-09-06 15:51:54 (9.24 MB/s) - ‘dnds/XP_033212670.1/KAG5873401.1/nuc.fasta’ saved [4023]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:55--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAG5873401.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAG5873401.1/prot.fasta’
#
#      0K .                                                      62.3M=0s
#
# 2023-09-06 15:51:55 (62.3 MB/s) - ‘dnds/XP_033212670.1/KAG5873401.1/prot.fasta’ saved [1294]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:55--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH1725386.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH1725386.1/nuc.fasta’
#
#      0K ....                                                    102M=0s
#
# 2023-09-06 15:51:56 (102 MB/s) - ‘dnds/XP_033212670.1/CAH1725386.1/nuc.fasta’ saved [4318]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:57--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH1725386.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH1725386.1/prot.fasta’
#
#      0K .                                                      49.0M=0s
#
# 2023-09-06 15:51:57 (49.0 MB/s) - ‘dnds/XP_033212670.1/CAH1725386.1/prot.fasta’ saved [1337]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:57--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_046436801.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_046436801.1/nuc.fasta’
#
#      0K .....                                                   146M=0s
#
# 2023-09-06 15:51:57 (146 MB/s) - ‘dnds/XP_033212670.1/XP_046436801.1/nuc.fasta’ saved [5557]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:58--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_046436801.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_046436801.1/prot.fasta’
#
#      0K .                                                      72.9M=0s
#
# 2023-09-06 15:51:58 (72.9 MB/s) - ‘dnds/XP_033212670.1/XP_046436801.1/prot.fasta’ saved [1864]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:51:58--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAJ6641516.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAJ6641516.1/nuc.fasta’
#
#      0K .....                                                  49.9M=0s
#
# 2023-09-06 15:51:59 (49.9 MB/s) - ‘dnds/XP_033212670.1/KAJ6641516.1/nuc.fasta’ saved [5695]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:00--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAJ6641516.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAJ6641516.1/prot.fasta’
#
#      0K .                                                      68.3M=0s
#
# 2023-09-06 15:52:01 (68.3 MB/s) - ‘dnds/XP_033212670.1/KAJ6641516.1/prot.fasta’ saved [1761]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:01--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAD7409286.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAD7409286.1/nuc.fasta’
#
#      0K ...                                                     139M=0s
#
# 2023-09-06 15:52:01 (139 MB/s) - ‘dnds/XP_033212670.1/CAD7409286.1/nuc.fasta’ saved [3837]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:01--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAD7409286.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAD7409286.1/prot.fasta’
#
#      0K .                                                      52.3M=0s
#
# 2023-09-06 15:52:02 (52.3 MB/s) - ‘dnds/XP_033212670.1/CAD7409286.1/prot.fasta’ saved [1224]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:02--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_046480902.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_
1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_011647979.1/nuc.fasta’
#
#      0K ......                                                 53.1M=0s
#
# 2023-09-06 15:52:10 (53.1 MB/s) - ‘dnds/XP_033212670.1/XP_011647979.1/nuc.fasta’ saved [6344]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:10--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_011647979.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_011647979.1/prot.fasta’
#
#      0K ..                                                     21.9M=0s
#
# 2023-09-06 15:52:10 (21.9 MB/s) - ‘dnds/XP_033212670.1/XP_011647979.1/prot.fasta’ saved [2156]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:10--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_048487769.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_048487769.1/nuc.fasta’
#
#      0K ....                                                   36.2M=0s
#
# 2023-09-06 15:52:11 (36.2 MB/s) - ‘dnds/XP_033212670.1/XP_048487769.1/nuc.fasta’ saved [4434]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:11--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_048487769.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_048487769.1/prot.fasta’
#
#      0K .                                                      15.1M=0s
#
# 2023-09-06 15:52:11 (15.1 MB/s) - ‘dnds/XP_033212670.1/XP_048487769.1/prot.fasta’ saved [1472]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:11--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0546293.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0546293.1/nuc.fasta’
#
#      0K ....                                                    111M=0s
#
# 2023-09-06 15:52:12 (111 MB/s) - ‘dnds/XP_033212670.1/CAH0546293.1/nuc.fasta’ saved [4126]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:12--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH0546293.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH0546293.1/prot.fasta’
#
#      0K .                                                      50.3M=0s
#
# 2023-09-06 15:52:13 (50.3 MB/s) - ‘dnds/XP_033212670.1/CAH0546293.1/prot.fasta’ saved [1303]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:13--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAG8200350.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAG8200350.1/nuc.fasta’
#
#      0K .....                                                  45.0M=0s
#
# 2023-09-06 15:52:13 (45.0 MB/s) - ‘dnds/XP_033212670.1/KAG8200350.1/nuc.fasta’ saved [5618]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:13--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=KAG8200350.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/KAG8200350.1/prot.fasta’
#
#      0K .                                                      19.0M=0s
#
# 2023-09-06 15:52:14 (19.0 MB/s) - ‘dnds/XP_033212670.1/KAG8200350.1/prot.fasta’ saved [1884]
#
# URL transformed to HTTPS due to an HSTS policy
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_050508717.1/prot.fasta’
#
#      0K .                                                      52.7M=0s
#
# 2023-09-06 15:52:20 (52.7 MB/s) - ‘dnds/XP_033212670.1/XP_050508717.1/prot.fasta’ saved [1304]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:20--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_050544882.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_050544882.1/nuc.fasta’
#
#      0K ....                                                   33.1M=0s
#
# 2023-09-06 15:52:21 (33.1 MB/s) - ‘dnds/XP_033212670.1/XP_050544882.1/nuc.fasta’ saved [4118]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:21--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_050544882.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_050544882.1/prot.fasta’
#
#      0K .                                                      51.7M=0s
#
# 2023-09-06 15:52:22 (51.7 MB/s) - ‘dnds/XP_033212670.1/XP_050544882.1/prot.fasta’ saved [1396]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:22--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH2039510.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH2039510.1/nuc.fasta’
#
#      0K ...                                                     148M=0s
#
# 2023-09-06 15:52:23 (148 MB/s) - ‘dnds/XP_033212670.1/CAH2039510.1/nuc.fasta’ saved [3286]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:23--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=CAH2039510.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/CAH2039510.1/prot.fasta’
#
#      0K                                                        50.1M=0s
#
# 2023-09-06 15:52:23 (50.1 MB/s) - ‘dnds/XP_033212670.1/CAH2039510.1/prot.fasta’ saved [1017]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:23--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_032666246.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_032666246.1/nuc.fasta’
#
#      0K .....                                                   155M=0s
#
# 2023-09-06 15:52:24 (155 MB/s) - ‘dnds/XP_033212670.1/XP_032666246.1/nuc.fasta’ saved [5363]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:24--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_032666246.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP

#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:33--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_047534808.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_047534808.1/prot.fasta’
#
#      0K .                                                      69.2M=0s
#
# 2023-09-06 15:52:34 (69.2 MB/s) - ‘dnds/XP_033212670.1/XP_047534808.1/prot.fasta’ saved [1459]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:34--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_011693066.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_011693066.1/nuc.fasta’
#
#      0K .....                                                  95.7M=0s
#
# 2023-09-06 15:52:34 (95.7 MB/s) - ‘dnds/XP_033212670.1/XP_011693066.1/nuc.fasta’ saved [5960]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:34--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_011693066.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_011693066.1/prot.fasta’
#
#      0K .                                                      84.6M=0s
#
# 2023-09-06 15:52:35 (84.6 MB/s) - ‘dnds/XP_033212670.1/XP_011693066.1/prot.fasta’ saved [2012]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:35--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_047516373.1&rettype=fasta_cds_na
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dnds/XP_033212670.1/XP_047516373.1/nuc.fasta’
#
#      0K ....                                                    102M=0s
#
# 2023-09-06 15:52:36 (102 MB/s) - ‘dnds/XP_033212670.1/XP_047516373.1/nuc.fasta’ saved [4282]
#
# URL transformed to HTTPS due to an HSTS policy
# --2023-09-06 15:52:36--  https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&id=XP_047516373.1&rettype=fasta
# Resolving eutils.ncbi.nlm.nih.gov... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to eutils.ncbi.nlm.nih.gov|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response...

# %% [markdown]
# # Producing codon alignments and running PAML M0 model fitting

# %%
for c in dfc[dfc.n_species>1].sort_values("n_species").index:
    if "paml_output.out" not in os.listdir(f"dnds/{c}"):
        print(c,dfc.loc[c,"n_species"])
        input_file = open(f"dnds/{c}/MSA_concatenated_prot.fasta")
        prot_dict = SeqIO.to_dict(SeqIO.parse(input_file, "fasta"))
        input_file = open(f"dnds/{c}/concatenated_nuc.fasta")
        nuc_dict = SeqIO.to_dict(SeqIO.parse(input_file, "fasta"))
        #make sure msa and nucleotide fasta are in the same order 
        f=open(f"dnds/{c}/concatenated_nuc.fasta","w")
        f1=open(f"dnds/{c}/MSA_concatenated_prot.fasta","w")
        for p in prot_dict.keys():
            kn=[x for x in nuc_dict.keys() if p in x]
            if len(kn)>0:
                kn=kn[0]
                f.write(f">{kn}")
                f.write("\n")
                f.write(str(nuc_dict[kn].seq))
                f.write("\n")

                f1.write(f">{p}")
                f1.write("\n")
                f1.write(str(prot_dict[p].seq))
                f1.write("\n")
        f.close()
        f1.close()
        #produce a gapless codon alignment guided by the MSA 
        subprocess.run(["sh","dnds_scripts/run_pal2nal.sh", "dnds",str(c)])
        #run codeml to get gene-wide dn/ds value
        subprocess.run(["sbatch","dnds_scripts/run_paml_m0.sh", str(c)])
# Out:
# XP_029662819.1 368.0
# WARNING: Skipping mount /var/lib/singularity/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = (unset),
# 	LC_ALL = "en_US.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to the standard locale ("C").
# Submitted batch job 1997305

# %% [markdown]
# Rerunning M0 with dn/ds fixed at 1 (neutral)

# %%
for c in dfc[dfc.n_species>1].sort_values("n_species").index:
    subprocess.run(["sbatch","dnds_scripts/run_fixed_paml_whole_gene.sh", str(c)])

# %% [markdown]
# ## Producing a summary table of dn/ds values and running an LRT (dn/ds<1)

# %%
dnds_data=pd.DataFrame(index=dfc[dfc.n_species>1].sort_values("n_species").representative_seq, columns=["dnds_f","lnL_f","np_f","dS_f","lnL_1","np_1"])

# %%
import numpy as np
import scipy 
from scipy import stats
# Out:
# /n/home11/rkapoor/.conda/envs/rishabh/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
gene_dnds={}
fails=[]
for c in dfc[dfc.n_species>1].sort_values("n_species").representative_seq:
    
    
    if "paml_output.out" in os.listdir(f"dnds/{c}") and "tree.newick" in os.listdir(f"dnds/{c}"):
       
        f=open(f"dnds/{c}/paml_output.out","r").readlines()
        t=False
        for i  in range(len(f)):
            x=f[i]
            if "omega (dN/dS) =" in x:
                dnds_data.loc[c,"dnds_f"]=ast.literal_eval(x.split("omega (dN/dS) =")[1].strip())
                
                t=True
            if "lnL(" in x:
                dnds_data.loc[c,"np_f"]=ast.literal_eval(x.split("lnL(")[1].split("np:")[1].split(")")[0].strip())
                dnds_data.loc[c,"lnL_f"]=ast.literal_eval(x.split("):")[1].strip().split()[0])
            if "tree length for dS:" in x:
                dnds_data.loc[c,"dS_f"]=ast.literal_eval(x.split("tree length for dS:")[1].strip().split()[0])
            if "Printing out site pattern counts" in x:
            
                dnds_data.loc[c,"n_codons"]=ast.literal_eval(f[i+3].split()[1])/3
        if t==False:
            fails.append(c)
    else:
        print("no_paml"+c)
        fails.append(c)

# %%
for c in dfc[dfc.n_species>1].sort_values("n_species").representative_seq:
    
    
    if "fix_omega_paml_output.out" in os.listdir(f"dnds/{c}") and "tree.newick" in os.listdir(f"dnds/{c}"):
       
        f=open(f"dnds/{c}/fix_omega_paml_output.out","r").readlines()
        t=False
        for x in f:
           
            if "lnL(" in x:
                dnds_data.loc[c,"np_1"]=ast.literal_eval(x.split("lnL(")[1].split("np:")[1].split(")")[0].strip())
                dnds_data.loc[c,"lnL_1"]=ast.literal_eval(x.split("):")[1].strip().split()[0])
            
        if t==False:
            fails.append(c)
    else:
        print("no_paml"+c)
        fails.append(c)

# %%
dnds_data["delta_p"]=np.array(dnds_data["np_f"])-np.array(dnds_data["np_1"])
dnds_data["2*delta_L"]=2*(np.array(dnds_data["lnL_f"])-np.array(dnds_data["lnL_1"]))
# rum likelihood ratio test comparing dnds to dnds fixed at 1 
for index, row in dnds_data.iterrows():
    dnds_data.loc[index,"p_val"]=scipy.stats.chi2.sf(row["2*delta_L"],row["delta_p"])

# %%
from statsmodels.stats.multitest import multipletests

# Example p-values
p_values = dnds_data.p_val.iloc[0:-1]

# Perform Benjamini-Hochberg correction
corrected_p_values =list( multipletests(p_values, method='fdr_bh')[1])
corrected_p_values.append(np.nan)

# %%
dnds_data.loc[:,"p_val_corrected"]=corrected_p_values

# %%
dnds_data
# Out:
#                      dnds_f         lnL_f np_f      dS_f         lnL_1 np_1  \
# representative_seq
# XP_029821973.3      0.33971  -2896.683786    7       0.4   -2919.54979    6
# XP_046439036.1      0.36748  -3431.617749    7    0.0204  -3434.389367    6
# XP_021699539.1      0.30439   -7742.86807    7    1.0528  -7840.067198    6
# XP_049881676.1      0.00734  -2898.277154    7  126.5068  -2914.117364    6
# XP_027204138.1      0.00169  -5858.335847    7  152.7057  -6133.573558    6
# XP_035711638.1      0.02834  -8180.030814    7   35.4748  -8242.731855    6
# XP_023329593.1      0.00459    -4670.2091    7  135.6057  -4783.747655    6
# XP_041972388.1      0.08296  -9127.450001    8    4.0719  -9711.510462    7
# XP_037790819.1      0.29018  -6420.677218    8    0.4281  -6507.937074    7
# XP_046649021.1      0.12071  -5290.319972   10    2.0238   -5579.37103    9
# XP_046456339.1      0.39374 -15519.176284   12    2.9491 -15695.771151   11
# XP_042220148.1      0.28747  -6927.960834   14    3.0522  -7079.816072   13
# XP_044763649.1      0.08118 -10614.910148   14   16.0095  -11279.66955   13
# XP_034827763.1       0.1279  -5872.039419   16    7.7606  -6223.795132   15
# XP_035715507.1      0.08605  -5617.360609   24   36.6745  -5837.416547   23
# XP_050528041.1      0.24262  -6368.051889   38    7.2266  -6557.428936   37
# XP_034487048.1      0.13841 -24628.504695  306   97.3749 -26344.882725  305
#
#                     n_codons delta_p    2*delta_L          p_val  \
# representative_seq
# XP_029821973.3         196.0       1    45.732008   1.355890e-11
# XP_046439036.1          85.0       1     5.543236   1.855225e-02
# XP_021699539.1         563.0       1   194.398256   3.486125e-44
# XP_049881676.1         319.0       1     31.68042   1.817453e-08
# XP_027204138.1         413.0       1   550.475422  9.921255e-122
# XP_035711638.1         756.0       1   125.402082   4.155993e-29
# XP_023329593.1         437.0       1    227.07711   2.586983e-51
# XP_041972388.1         708.0       1  1168.120922  5.171182e-256
# XP_037790819.1         400.0       1   174.519712   7.622370e-40
# XP_046649021.1         441.0       1   578.102116  9.703095e-128
# XP_046456339.1        1015.0       1   353.189734   8.561280e-79
# XP_042220148.1         475.0       1   303.710476   5.121532e-68
# XP_044763649.1         670.0       1  1329.518804  4.349373e-291
# XP_034827763.1         326.0       1   703.511426  5.153760e-155
# XP_035715507.1         182.0       1   440.111876   1.023523e-97
# XP_050528041.1         265.0       1   378.754094   2.323891e-84
# XP_034487048.1         117.0       1   3432.75606   0.000000e+00
#
#                     p_val_corrected
# representative_seq
# XP_029821973.3         1.549589e-11
# XP_046439036.1         1.855225e-02
# XP_021699539.1         5.070727e-44
# XP_049881676.1         1.938617e-08
# XP_027204138.1        3.174802e-121
# XP_035711638.1         5.115069e-29
# XP_023329593.1         4.139172e-51
# XP_041972388.1        4.136946e-255
# XP_037790819.1         1.016316e-39
# XP_046649021.1        3.881238e-127
# XP_046456339.1         1.712256e-78
# XP_042220148.1         9.104946e-68
# XP_044763649.1        6.958997e-290
# XP_034827763.1        2.748672e-154
# XP_035715507.1         2.729395e-97
# XP_050528041.1         5.311750e-84
# XP_034487048.1                  NaN

# %%
dnds_data.to_csv("whole_gene_dnds.csv")

# %% [markdown]
# ## Partition (Fixed-Site) Models

# %%
import ast

# %%
hgt_inters=[]
for index, row in dfc.iterrows():
    hgt_inters.extend(ast.literal_eval(row.HGT_intervals))

# %%
to_do=[]
for x in dfc[dfc.n_species>1].representative_seq:
    if "m2_paml_output.out" not in os.listdir(f"dnds/{x}"):
        to_do.append(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 to_do=[]
# ----> 2 for x in dfc[dfc.n_species>1].representative_seq:
#       3     if "m2_paml_output.out" not in os.listdir(f"dnds/{x}"):
#       4         to_do.append(x)
#
# File ~/.conda/envs/rishabh/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'representative_seq'

# %%
file=open("partion_model_fail.txt","w")
for c in dfc[dfc.n_species>1].representative_seq:
    if "tree.newick" in os.listdir(f"dnds/{c}"):
        try:
            ##run pal2nal to get a codon alignment with both amino acids and codons (including gaps)
            subprocess.run(["sh","dnds_scripts/run_pal2nal_codon.sh", str(c)])
            lines=open(f"dnds/{c}/pal2nal.codon","r").readlines()

            lines=[x.replace("\n","") for x in lines]
            prot_al={}
            nuc_al={}
            for i in range(len(lines)-1):
                l=lines[i].split()
                if len(l)>1:
                    if len(l[0])>3:

                        key=l[0]
                        if key not in nuc_al:
                            nuc_al[key]=l[1:]
                        else:
                            tl=nuc_al[key]
                            tl.extend(l[1:])
                            nuc_al[key]=tl
                    elif len(l[0])==1:

                        key=lines[i+1].split()[0]
                        if key not in prot_al:
                            prot_al[key]=l[1:]
                        else:
                            tl=prot_al[key]
                            tl.extend(l[1:])
                            prot_al[key]=tl
            ##produce a list of indices in the gapless alignment from the residue position in the representative chimera
            pos_ch=[]
            ch_index=0
            for i in range(len(nuc_al[c])):
                if nuc_al[c][i]!='---':
                    ch_index+=1
                if len([gene for gene in nuc_al.keys() if nuc_al[gene][i]=="---" or nuc_al[gene][i]=="TAA" or nuc_al[gene][i]=="TAG" or nuc_al[gene][i]=="TGA"])==0:
                    pos_ch.append(ch_index)

            inters=[x for x in hgt_inters if c in x]
            
            #write a paml configuration with residues in the hgt interval(s) marked as site type '2'
            #other residues marked as site type '1'
            for inter in inters:
                if inter not in os.listdir(f"dnds/{c}"):
                    print(inter)
                    try:
                        subprocess.run(["rm","-r",f"dnds/{c}/{inter}"])
                    except:
                        p=1
                    try:
                        os.mkdir(f"dnds/{c}/{inter}")
                    except:
                        p=1
                    interi=ast.literal_eval(inter.split("_")[-1])

                    f=open(f"dnds/{c}/pal2nal.paml","r").readlines()
                    f1=open(f"dnds/{c}/{inter}/fs_pal2nal.paml","w")
                    f[0].replace("\n","G \n")
                    f1.write(f[0].replace("\n","G \n"))
                    f1.write("G2")
                    f1.write("\n")
                    flags=[str(int(x>=interi[0] and x<=interi[1])+1) for x in pos_ch]
                    f1.write("".join(flags))
                    f1.write("\n")
                    for x in f[1:]:
                        f1.write(x)
                    f1.close()
                    subprocess.run(["sbatch","dnds_scripts/run_partition_paml.sh",str(c),inter])
        except:
            file.write(c)
            file.write("\n")
file.close()
# Out:
# WARNING: Skipping mount /var/lib/singularity/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = (unset),
# 	LC_ALL = "en_US.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to the standard locale ("C").
# GCF_010883055.1;XP_033212670.1;HGT_(19,106)
# rm: cannot remove 'dnds/XP_033212670.1/GCF_010883055.1;XP_033212670.1;HGT_(19,106)': No such file or directory
# Submitted batch job 1999128
# WARNING: Skipping mount /var/lib/singularity/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = (unset),
# 	LC_ALL = "en_US.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to the standard locale ("C").
# GCF_003651465.1;XP_029662819.1;HGT_(20,127)
# rm: cannot remove 'dnds/XP_029662819.1/GCF_003651465.1;XP_029662819.1;HGT_(20,127)': No such file or directory
# Submitted batch job 1999136

# %%
pdnds=pd.DataFrame()

# %%
for c in dfc[dfc.n_species>1].representative_seq:
    inters=[x for x in hgt_inters if c in x]
    for inter in inters:
        try:
            lines=open(f"dnds/{c}/{inter}/fs_pal2nal.paml", "r").readlines()
            pdnds.loc[inter,"nsites_2"]=len([x for x in lines[2].strip() if x=='2'])
            pdnds.loc[inter,"nsites"]=len(lines[2].strip())
        except:
            p=1
        try:
            lines=open(f"dnds/{c}/{inter}/m2_paml_output.out", "r").readlines()
            for x in lines:
                if "omega (dN/dS) =" in x:
                    pdnds.loc[inter,"dnds_f"]=ast.literal_eval(x.split("omega (dN/dS) =")[1].strip())
                if "lnL(" in x:
                    pdnds.loc[inter,"np_f"]=ast.literal_eval(x.split("lnL(")[1].split("np:")[1].split(")")[0].strip())
                    pdnds.loc[inter,"lnL_f"]=ast.literal_eval(x.split("):")[1].strip().split()[0])
        except:
            print(inter)
            
        try:
            lines=open(f"dnds/{c}/{inter}/m4_paml_output.out", "r").readlines()
            for x in lines:
                if "gene # 1: kappa =" in x:
                    pdnds.loc[inter,"dnds_1"]=ast.literal_eval(x.split("omega =")[1].strip())
                if "gene # 2: kappa =" in x:
                    pdnds.loc[inter,"dnds_2"]=ast.literal_eval(x.split("omega =")[1].strip())
                if "lnL(" in x:
                    pdnds.loc[inter,"np_p"]=ast.literal_eval(x.split("lnL(")[1].split("np:")[1].split(")")[0].strip())
                    pdnds.loc[inter,"lnL_p"]=ast.literal_eval(x.split("):")[1].strip().split()[0])
                
        except:
            print(inter)
# Out:
# GCF_024362695.1;XP_049881676.1;HGT_(1,78)
# GCF_024362695.1;XP_049881676.1;HGT_(1,78)

# %%
pdnds["delta_p"]=np.array(pdnds["np_p"])-np.array(pdnds["np_f"])
pdnds["2*delta_L"]=2*(np.array(pdnds["lnL_p"])-np.array(pdnds["lnL_f"]))
for index, row in pdnds.iterrows():
    pdnds.loc[index,"p_val"]=scipy.stats.chi2.sf(row["2*delta_L"],row["delta_p"])

# %%
pdnds=pdnds.dropna(axis=0)

# %%
p_values = pdnds.p_val

# Perform Benjamini-Hochberg correction
corrected_p_values = multipletests(p_values, method='fdr_bh')[1]

correct_p_values=list(corrected_p_values)
pdnds.loc[:,"correct_p_values"]=correct_p_values

# %%
pdnds['prot']=[x.split(";")[1].split(";")[0] for x in pdnds.index]
for index, row in pdnds.iterrows():
    pdnds.loc[index,'cluster']=dfc[dfc.representative_seq==row.prot].index.values[0]
    pdnds.loc[index,'interval']="'"+index.split("_")[-1]+"'"

# %%
pdnds=pdnds.set_index("prot")

# %%
pdnds.loc[:,['cluster', 'interval','nsites_2', 'nsites', 'np_f', 'lnL_f', 'dnds_f', 'np_p', 'lnL_p',
       'dnds_1', 'dnds_2', 'delta_p', '2*delta_L', 'p_val', 'correct_p_values']].to_csv("data_upload_3_24_2025/Supplementary Table XIII_ partition model dN_dS - partition model dnd_s.tsv")

# %%
pdnds.to_csv("data_upload_3_24_2025/Supplementary Table XIII_ partition model dN_dS - partition model dnd_s.tsv",sep="\t")

# %% [markdown]
# ## Figure 5D-E

# %%
pdnds=pd.read_csv("data_upload_3_24_2025/Supplementary Table XIII_ partition model dN_dS - partition model dnd_s.tsv",sep="\t",index_col=0)

# %%
dnds_data=pd.read_csv("data_upload_3_24_2025/Supplementary Table XII_ gene-wide dN_dS - whole_gene_dnds.csv",index_col=0)

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt

import matplotlib.font_manager
from matplotlib.font_manager import FontProperties

import matplotlib as mpl
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
fpath = Path(mpl.get_data_path(), "/n/holylabs/LABS/extavour_lab/Users/rkapoor/envs/plot/fonts/arial.ttf")
from matplotlib.font_manager import FontProperties
from matplotlib import font_manager
plt.rcParams['figure.dpi'] = 300
font_path = "/n/holylabs/LABS/extavour_lab/Users/rkapoor/envs/plot/fonts/arial.ttf"
font_manager.fontManager.addfont("/n/holylabs/LABS/extavour_lab/Users/rkapoor/envs/plot/fonts/arial.ttf")
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()
plt.rcParams['svg.fonttype']='none'

# %%
pdnds
# Out:
#                 nsites_2  nsites   np_f         lnL_f   dnds_f   np_p  \
# prot
# XP_034487048.1      42.0   117.0  304.0 -25145.328927  0.12936  306.0
# XP_050528041.1      45.0   265.0   36.0  -6500.959093  0.19315   38.0
# XP_035715507.1     108.0   185.0   22.0  -5717.872268  0.08405   24.0
# XP_034827763.1     204.0   339.0   14.0  -5924.881911  0.08286   16.0
# XP_044763649.1     549.0   682.0   12.0 -10823.828960  0.05449   14.0
# XP_042220148.1     147.0   504.0   12.0  -7058.727976  0.26874   14.0
# XP_046456339.1     199.0  1075.0   10.0 -15724.492356  0.35579   12.0
# XP_046649021.1     183.0   640.0    8.0  -5435.336023  0.10409   10.0
# XP_037790819.1     428.0  1020.0    6.0  -6508.883651  0.27660    8.0
# XP_041972388.1     431.0  1031.0    6.0  -9206.707942  0.04496    8.0
# XP_027204138.1     290.0   923.0    5.0  -5967.381855  0.02119    7.0
# XP_035711638.1     347.0  1067.0    5.0  -8333.212601  0.00716    7.0
# XP_029821973.3     170.0   514.0    5.0  -2926.062646  0.26466    7.0
# XP_046439036.1      63.0   824.0    5.0  -3517.618285  0.38622    7.0
# XP_021699539.1     145.0  1158.0    5.0  -7861.529911  0.24700    7.0
# XP_021699539.1     135.0  1158.0    5.0  -7857.059681  0.24157    7.0
# XP_023329593.1      53.0   629.0    5.0  -4775.965619  0.00489    7.0
#
#                        lnL_p   dnds_1   dnds_2  delta_p  2*delta_L  \
# prot
# XP_034487048.1 -25138.698301  0.13653  0.11666      2.0  13.261252
# XP_050528041.1  -6500.718382  0.19710  0.17131      2.0   0.481422
# XP_035715507.1  -5717.578813  0.07845  0.09008      2.0   0.586910
# XP_034827763.1  -5923.287863  0.07782  0.08704      2.0   3.188096
# XP_044763649.1 -10819.344297  0.09268  0.04841      2.0   8.969326
# XP_042220148.1  -7058.020573  0.28056  0.24234      2.0   1.414806
# XP_046456339.1 -15712.260435  0.38850  0.24113      2.0  24.463842
# XP_046649021.1  -5416.746858  0.14252  0.04017      2.0  37.178330
# XP_037790819.1  -6505.233972  0.34231  0.20970      2.0   7.299358
# XP_041972388.1  -9203.538180  0.03770  0.06099      2.0   6.339524
# XP_027204138.1  -5969.319290  0.00655  0.00021      2.0  -3.874870
# XP_035711638.1  -8332.485820  0.04218  0.00036      2.0   1.453562
# XP_029821973.3  -2920.892895  0.22905  0.33443      2.0  10.339502
# XP_046439036.1  -3517.614258  0.38624  0.00010      2.0   0.008054
# XP_021699539.1  -7859.866319  0.23278  0.37739      2.0   3.327184
# XP_021699539.1  -7855.340989  0.22814  0.39973      2.0   3.437384
# XP_023329593.1  -4776.502622  0.01657  0.00017      2.0  -1.074006
#
#                        p_val  correct_p_values  cluster      interval
# prot
# XP_034487048.1  1.319337e-03      7.476243e-03      1.0   '(412,553)'
# XP_050528041.1  7.860688e-01      9.545121e-01      2.0    '(34,150)'
# XP_035715507.1  7.456828e-01      9.545121e-01      3.0   '(127,249)'
# XP_034827763.1  2.031018e-01      3.452730e-01      4.0    '(34,408)'
# XP_044763649.1  1.128069e-02      3.835434e-02      5.0   '(158,738)'
# XP_042220148.1  4.929227e-01      6.983071e-01      6.0   '(352,559)'
# XP_046456339.1  4.872414e-06      4.141552e-05      7.0    '(49,253)'
# XP_046649021.1  8.449446e-09      1.436406e-07      8.0   '(451,633)'
# XP_037790819.1  2.599947e-02      7.366517e-02      9.0  '(738,1165)'
# XP_041972388.1  4.201360e-02      1.020330e-01     10.0    '(56,486)'
# XP_027204138.1  1.000000e+00      1.000000e+00     11.0   '(128,420)'
# XP_035711638.1  4.834628e-01      6.983071e-01     12.0   '(420,827)'
# XP_029821973.3  5.685984e-03      2.416543e-02     13.0   '(313,947)'
# XP_046439036.1  9.959811e-01      1.000000e+00     14.0     '(17,79)'
# XP_021699539.1  1.894572e-01      3.452730e-01     16.0   '(190,334)'
# XP_021699539.1  1.793005e-01      3.452730e-01     16.0   '(385,523)'
# XP_023329593.1  1.000000e+00      1.000000e+00     17.0   '(204,256)'

# %%
fig,ax=plt.subplots(1,2,dpi=300,figsize=(10,3))
ax[0].scatter(np.log10(dnds_data.p_val_corrected+1e-300),dnds_data.dnds_f,s=20,color='black')
ax[0].vlines(np.log10(.05),-.1,1.5,color='black',linestyle='dashed',label="p_adj=.05",linewidth=1)
ax[0].hlines(1,-320,20,color='black',linewidth=1)
ax[0].set_ylim(-.1,1.3)
ax[0].set_xlim(-310,20)
ax[0].set_title("A. Gene-wide dN/dS" )
ax[0].set_ylabel("dN/dS")
ax[0].set_xlabel("log10(FDR-p value+1e-300) for LRT vs dN/dS=1")


ax[1].scatter(pdnds.dnds_1,pdnds.dnds_2,color='black',s=20)
ax[1].scatter(pdnds[pdnds.correct_p_values < .05].dnds_1,
            pdnds[pdnds.correct_p_values < .05].dnds_2,
            color='white',
            edgecolor='black',  # Add black outline to points
            label="p_adj<.05",
            s=20)
ax[1].plot(np.linspace(0,.8,10),np.linspace(0,.8,10),label="y=x",color='black',linestyle='dashed')
ax[1].set_xlim(-0.05,.5)
ax[1].set_ylim(-.05,.5)
ax[1].legend()
ax[1].set_xlabel("dN/dS for non-HGT codons")
ax[1].set_ylabel("dN/dS for HGT codons")
ax[1].set_title("B. dN/dS partioned by HGT ancestry")


plt.savefig("combined_partition_dnds.svg",format='svg')
plt.show()
